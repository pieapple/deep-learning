# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /Users/zhiholiu/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [02:11, 238kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_word_counts = len(int_words)

def discard_prop(word):
    freq = word_counts[word] / total_word_counts
    
    return 1 - np.sqrt(threshold/freq)

p_drop = {word: discard_prop(word) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = max(0, idx - R)
    end = min(len(words), idx + 1 + R)
    
    return set(words[start:idx] + words[(idx+1):end])

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None, ))
    labels = tf.placeholder(tf.int32, shape=(None, None))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6390 0.2015 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6520 0.1927 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4958 0.2086 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5994 0.1993 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5480 0.2220 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5384 0.2131 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5511 0.2059 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5373 0.2061 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4787 0.2067 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4475 0.2190 sec/batch
# Nearest to most: than, pine, horns, subsequent, confesses, gilgamesh, reith, nemean,
# Nearest to s: ashmole, lackey, protestors, exercising, ibsen, idols, testing, spalding,
# Nearest to first: berners, heisman, paint, cermak, hay, explicated, lsi, nusa,
# Nearest to is: pris, neurobiology, subsistence, forcefully, hybridization, quadrant, categories, guarantees,
# Nearest to about: spam, manicheanism, aloes, pendulum, macguffin, gerald, stylistically, programmers,
# Nearest to may: artchive, magee, stopwatch, reader, pediment, kayaking, readily, guadalajara,
# Nearest to its: legs, gonz, staunchly, trichechus, outlying, sidewinder, fraught, rawls,
# Nearest to th: teixeira, cts, etiquette, propagandists, jumblatt, geomagnetic, glissandi, maradona,
# Nearest to animals: irredentism, gallipoli, ilyich, cal, contributes, puddle, patay, turban,
# Nearest to experience: business, royalties, critics, nesuhi, geirr, herding, purim, nsted,
# Nearest to universe: anus, comnena, tank, congo, hylas, neglects, idolatrous, abnormalities,
# Nearest to marriage: artha, miya, napol, sauvage, swnt, erechtheus, hingle, barring,
# Nearest to engineering: myers, pads, slings, confessor, balaenoptera, rye, haq, bening,
# Nearest to assembly: subtypes, germain, concorde, barringer, enciclopedia, deletions, cordon, tunable,
# Nearest to quite: incapable, miyazaki, misr, onion, montesquieu, vicenza, antonyms, maize,
# Nearest to engine: mencken, prostitution, stallone, internalized, cultivation, subvert, maori, publicacion,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5285 0.2112 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3941 0.2146 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3332 0.2170 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2725 0.2078 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1731 0.2029 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2124 0.2037 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0896 0.2004 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0601 0.2028 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0155 0.2197 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9858 0.2257 sec/batch
# Nearest to most: than, pine, seems, subsequent, except, keep, merely, monarchy,
# Nearest to s: ashmole, lackey, quantity, testing, four, right, exercising, elementary,
# Nearest to first: heisman, post, paint, berners, cermak, mortimer, excised, condition,
# Nearest to is: categories, term, neurobiology, forcefully, quadrant, pris, subsistence, time,
# Nearest to about: spam, size, programmers, style, tradition, small, gerald, dangling,
# Nearest to may: reader, readily, magee, asserted, artchive, withdraw, stopwatch, urban,
# Nearest to its: legs, suggested, outlying, refers, gonz, boulevard, fraught, ferrand,
# Nearest to th: etiquette, lowest, teixeira, cts, domains, propagandists, problem, emerge,
# Nearest to animals: contributes, cal, arms, irredentism, gallipoli, thinkers, balancing, dominica,
# Nearest to experience: business, critics, physical, royalties, putting, python, why, depending,
# Nearest to universe: comnena, scientists, congo, ryswick, anus, hylas, nicht, idolatrous,
# Nearest to marriage: artha, napol, combat, miya, hingle, factories, organizing, cocteau,
# Nearest to engineering: myers, confessor, slings, wavelength, influenced, falls, haq, pads,
# Nearest to assembly: concorde, draws, subtypes, germain, enciclopedia, strikeouts, aligned, deletions,
# Nearest to quite: incapable, miyazaki, contributing, onion, montesquieu, independently, maize, for,
# Nearest to engine: mencken, cultivation, internalized, prostitution, agreements, views, instead, maori,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9436 0.2266 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9093 0.2242 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8962 0.2209 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8826 0.2108 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8401 0.2198 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8129 0.2184 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8058 0.2185 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7940 0.2117 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7724 0.2159 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7950 0.2137 sec/batch
# Nearest to most: monarchy, pine, seems, than, horns, involuntary, suppressed, keep,
# Nearest to s: ashmole, lackey, testing, polynesian, idols, four, sustained, quantity,
# Nearest to first: heisman, berners, paint, post, mortimer, heir, excised, strange,
# Nearest to is: neurobiology, categories, subsistence, forcefully, term, hoped, pris, royalties,
# Nearest to about: spam, gerald, size, programmers, informal, visually, daylight, structured,
# Nearest to may: reader, asserted, stopwatch, identically, magee, readily, artchive, emma,
# Nearest to its: outlying, legs, staunchly, duration, refers, gonz, fraught, distorts,
# Nearest to th: township, lowest, teixeira, ymca, domains, etiquette, maradona, hottest,
# Nearest to animals: gallipoli, arms, cal, contributes, ilyich, thinkers, irredentism, balancing,
# Nearest to experience: business, royalties, critics, physical, putting, graph, python, liquid,
# Nearest to universe: comnena, scientists, congo, hylas, ryswick, neglects, serialised, tank,
# Nearest to marriage: artha, napol, miya, altogether, combat, factories, barring, organizing,
# Nearest to engineering: myers, confessor, influenced, falls, slings, haq, wavelength, extinction,
# Nearest to assembly: draws, concorde, negotiating, enciclopedia, strikeouts, germain, aligned, galway,
# Nearest to quite: incapable, miyazaki, montesquieu, onion, contributing, maize, misr, sky,
# Nearest to engine: prostitution, agreements, mencken, cultivation, netherlands, internalized, subvert, furthering,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7597 0.2122 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7360 0.2077 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7311 0.2193 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6983 0.2192 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7598 0.2126 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7053 0.2357 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6999 0.2449 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7185 0.2308 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7268 0.2257 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6722 0.2277 sec/batch
# Nearest to most: pine, monarchy, seems, than, keep, confesses, horns, enforcement,
# Nearest to s: ashmole, lackey, four, protestors, polynesian, testing, conscientious, scratch,
# Nearest to first: heisman, berners, mortimer, heir, excised, hay, paint, post,
# Nearest to is: forcefully, neurobiology, categories, subsistence, quadrant, pris, oscillators, term,
# Nearest to about: spam, visually, stylistically, daylight, gerald, pendulum, informal, beta,
# Nearest to may: reader, stopwatch, magee, identically, artchive, readily, withdraw, asserted,
# Nearest to its: outlying, fraught, distorts, staunchly, legs, fanny, duration, ethos,
# Nearest to th: township, ymca, alain, geomagnetic, giancarlo, lowest, teixeira, jumblatt,
# Nearest to animals: gallipoli, ilyich, irredentism, cal, stoney, polemics, contributes, balancing,
# Nearest to experience: business, physical, putting, royalties, critics, graph, python, aids,
# Nearest to universe: congo, comnena, hylas, anus, scientists, tank, ryswick, neglects,
# Nearest to marriage: artha, napol, miya, factories, disciplined, sketches, sauvage, hingle,
# Nearest to engineering: myers, confessor, rye, slings, pads, haq, influenced, laborers,
# Nearest to assembly: negotiating, germain, concorde, smolensk, enciclopedia, draws, strikeouts, subtypes,
# Nearest to quite: incapable, miyazaki, onion, misr, maize, montesquieu, kbit, epitomized,
# Nearest to engine: prostitution, mencken, cultivation, agreements, netherlands, jaroslav, internalized, subvert,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6625 0.2218 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6926 0.2222 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6314 0.2277 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6294 0.2178 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6390 0.2127 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6311 0.2261 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6040 0.1729 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5382 0.2295 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5179 0.2069 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5064 0.2072 sec/batch
# Nearest to most: pine, monarchy, than, seems, keep, horns, confesses, solicitor,
# Nearest to s: ashmole, lackey, spalding, protestors, scratch, conscientious, pfa, andrew,
# Nearest to first: heisman, berners, heir, post, mortimer, beaufort, excised, paint,
# Nearest to is: forcefully, neurobiology, categories, quadrant, subsistence, pris, term, oscillators,
# Nearest to about: spam, stylistically, visually, dangling, daylight, manicheanism, informal, facilitation,
# Nearest to may: stopwatch, reader, identically, artchive, readily, magee, hurdles, banknote,
# Nearest to its: outlying, fraught, distorts, ethos, staunchly, trichechus, bordered, legs,
# Nearest to th: township, alain, teixeira, ymca, jumblatt, giancarlo, geomagnetic, glissandi,
# Nearest to animals: gallipoli, contributes, stoney, irredentism, cal, balancing, compasses, arms,
# Nearest to experience: physical, business, royalties, critics, putting, spitzer, python, why,
# Nearest to universe: anus, scientists, tidings, congo, neglects, tank, hylas, comnena,
# Nearest to marriage: artha, miya, napol, factories, disciplined, sauvage, hingle, panspermia,
# Nearest to engineering: myers, confessor, rye, pads, slings, haq, rain, wavelength,
# Nearest to assembly: smolensk, negotiating, elections, concorde, germain, enciclopedia, votes, subtypes,
# Nearest to quite: incapable, miyazaki, onion, misr, kbit, maize, cultivar, montesquieu,
# Nearest to engine: prostitution, mencken, cultivation, agreements, subvert, jaroslav, escalating, stallone,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4988 0.2130 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4820 0.2107 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4303 0.2082 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4945 0.2192 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4822 0.1997 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5038 0.2148 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4851 0.2304 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3992 0.2112 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4509 0.2119 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4265 0.2139 sec/batch
# Nearest to most: pine, monarchy, seems, keep, confesses, horns, homology, inflection,
# Nearest to s: ashmole, lackey, spalding, protestors, conscientious, andrew, woo, pfa,
# Nearest to first: heisman, berners, heir, post, excised, mortimer, recognizes, beaufort,
# Nearest to is: pris, forcefully, neurobiology, subsistence, categories, term, oscillators, quadrant,
# Nearest to about: spam, drc, stylistically, holdout, informal, facilitation, salman, aloes,
# Nearest to may: stopwatch, identically, readily, artchive, comprises, reader, matrices, analecta,
# Nearest to its: outlying, distorts, fraught, asp, staunchly, culturally, bordered, trichechus,
# Nearest to th: township, teixeira, alain, ymca, jumblatt, geomagnetic, giancarlo, glissandi,
# Nearest to animals: gallipoli, contributes, golfo, haircut, stoney, replicated, otherwise, cal,
# Nearest to experience: physical, critics, why, royalties, business, graph, python, putting,
# Nearest to universe: anus, scientists, tidings, tank, crusaders, neglects, congo, abnormalities,
# Nearest to marriage: artha, napol, miya, sauvage, cocteau, panspermia, stedman, assignments,
# Nearest to engineering: myers, rye, haq, pads, confessor, wavelength, bening, rain,
# Nearest to assembly: elections, smolensk, votes, negotiating, enciclopedia, concorde, germain, subtypes,
# Nearest to quite: incapable, miyazaki, maize, misr, kbit, onion, nameable, cultivar,
# Nearest to engine: prostitution, mencken, cultivation, subvert, jaroslav, internalized, stallone, agreements,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4490 0.2130 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4138 0.1991 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4194 0.1893 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4022 0.1888 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4063 0.1885 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4302 0.1888 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3785 0.1890 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3676 0.1865 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4240 0.2247 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3732 0.2093 sec/batch
# Nearest to most: pine, monarchy, seems, keep, inflection, confesses, horns, shotgun,
# Nearest to s: ashmole, lackey, spalding, pfa, conscientious, protestors, woo, clarendon,
# Nearest to first: heisman, berners, heir, post, excised, mortimer, cermak, beaufort,
# Nearest to is: pris, categories, forcefully, neurobiology, quantized, isomorphic, subsistence, specifies,
# Nearest to about: spam, drc, holdout, facilitation, aloes, stylistically, itv, salman,
# Nearest to may: stopwatch, identically, readily, comprises, hurdles, artchive, embouchure, asserted,
# Nearest to its: outlying, distorts, fraught, culturally, trichechus, asp, bordered, ethos,
# Nearest to th: township, teixeira, ymca, alain, jumblatt, giancarlo, pandemic, geomagnetic,
# Nearest to animals: replicated, contributes, golfo, water, haircut, institutionalization, stoney, gallipoli,
# Nearest to experience: why, physical, critics, royalties, putting, suevi, business, credible,
# Nearest to universe: anus, tidings, scientists, tank, crusaders, serialised, abnormalities, neglects,
# Nearest to marriage: miya, artha, napol, sauvage, panspermia, disciplined, stedman, cocteau,
# Nearest to engineering: wavelength, pads, rye, myers, haq, marketing, mechanical, buyer,
# Nearest to assembly: elections, votes, negotiating, smolensk, enciclopedia, cabinet, terrorism, vote,
# Nearest to quite: incapable, miyazaki, onion, cultivar, antonyms, maize, nameable, misr,
# Nearest to engine: engines, turbine, fuel, cultivation, mencken, prostitution, internalized, switch,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3687 0.2034 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3831 0.2036 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3421 0.2108 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3733 0.1939 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4026 0.2024 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3789 0.1929 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3747 0.2176 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4017 0.2087 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3200 0.2076 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3247 0.2068 sec/batch
# Nearest to most: monarchy, seems, pine, unseated, inflection, vagaries, homology, horns,
# Nearest to s: lackey, ashmole, spalding, protestors, conscientious, alexandrovna, pfa, four,
# Nearest to first: heisman, heir, berners, post, was, excised, cermak, revenues,
# Nearest to is: pris, categories, quantized, isomorphic, specifies, neurobiology, term, quadrant,
# Nearest to about: drc, spam, manicheanism, aloes, holdout, intramolecular, stylistically, daylight,
# Nearest to may: stopwatch, identically, readily, hurdles, comprises, banknote, artchive, asserted,
# Nearest to its: outlying, distorts, culturally, plymouth, asp, fraught, staunchly, trichechus,
# Nearest to th: township, teixeira, ymca, jumblatt, alain, geomagnetic, century, giancarlo,
# Nearest to animals: replicated, institutionalization, haircut, golfo, genus, water, contributes, rare,
# Nearest to experience: physical, why, credible, therefore, critics, putting, royalties, witnesses,
# Nearest to universe: anus, tidings, scientists, crusaders, tank, readings, abnormalities, aleinu,
# Nearest to marriage: artha, miya, napol, sauvage, stedman, cocteau, microarrays, disciplined,
# Nearest to engineering: wavelength, rye, myers, haq, marketing, mechanical, pads, buyer,
# Nearest to assembly: votes, elections, negotiating, smolensk, enciclopedia, terrorism, vote, amended,
# Nearest to quite: incapable, miyazaki, onion, cultivar, nameable, antonyms, maize, misr,
# Nearest to engine: engines, fuel, turbine, switch, mencken, generate, jaroslav, biodegradable,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3444 0.2121 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2892 0.2213 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3562 0.2118 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3869 0.2102 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3863 0.2173 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2714 0.2093 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2910 0.2072 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3463 0.2102 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2565 0.2125 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2888 0.2123 sec/batch
# Nearest to most: monarchy, unseated, pine, homology, bastions, seems, shotgun, keep,
# Nearest to s: lackey, ashmole, spalding, protestors, conscientious, alexandrovna, pfa, scratch,
# Nearest to first: heisman, heir, post, beaufort, was, excised, berners, cermak,
# Nearest to is: pris, quantized, categories, isomorphic, specifies, quadrant, oscillators, p,
# Nearest to about: drc, spam, intramolecular, aloes, holdout, manicheanism, facilitation, asclepius,
# Nearest to may: stopwatch, identically, hurdles, readily, analecta, artchive, comprises, guadalajara,
# Nearest to its: outlying, distorts, culturally, fraught, plymouth, asp, trichechus, ethos,
# Nearest to th: township, jumblatt, teixeira, alain, ymca, century, chechen, geomagnetic,
# Nearest to animals: haircut, genus, replicated, golfo, institutionalization, rare, water, conclusive,
# Nearest to experience: credible, why, physical, witnesses, python, therefore, critics, tautology,
# Nearest to universe: anus, tidings, scientists, crusaders, readings, zaghawa, hirelings, aleinu,
# Nearest to marriage: artha, miya, napol, sauvage, stedman, microarrays, cocteau, disciplined,
# Nearest to engineering: wavelength, mechanical, rye, marketing, haq, pads, faculty, myers,
# Nearest to assembly: elections, votes, negotiating, smolensk, vote, cabinet, amended, enciclopedia,
# Nearest to quite: incapable, miyazaki, onion, cultivar, antonyms, nameable, sky, misr,
# Nearest to engine: engines, turbine, fuel, switch, generate, cylinders, unlock, mencken,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2792 0.2125 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2811 0.2086 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3253 0.0974 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2510 0.2090 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2267 0.2085 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2045 0.2084 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2326 0.2140 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2144 0.2144 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2080 0.2090 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1757 0.2162 sec/batch
# Nearest to most: monarchy, unseated, pine, vagaries, inflection, horns, evolutions, bastions,
# Nearest to s: ashmole, spalding, lackey, alexandrovna, protestors, testing, pfa, wallop,
# Nearest to first: heisman, heir, was, post, punch, excised, berners, tug,
# Nearest to is: quantized, pris, specifies, p, oscillators, categories, pristine, isomorphic,
# Nearest to about: drc, aloes, intramolecular, facilitation, spam, manicheanism, daylight, tzar,
# Nearest to may: stopwatch, identically, comprises, readily, hurdles, banknote, guadalajara, analecta,
# Nearest to its: outlying, distorts, culturally, trichechus, fraught, asp, plymouth, ethos,
# Nearest to th: jumblatt, teixeira, township, century, alain, glissandi, pilgrims, baltic,
# Nearest to animals: genus, golfo, haircut, institutionalization, replicated, conclusive, marvellous, isocrates,
# Nearest to experience: credible, why, critics, witnesses, physical, therefore, contraband, royalties,
# Nearest to universe: tidings, anus, scientists, readings, hirelings, zaghawa, aleinu, crusaders,
# Nearest to marriage: artha, miya, napol, sauvage, stedman, microarrays, cocteau, shamash,
# Nearest to engineering: mechanical, rye, wavelength, marketing, electronics, myers, faculty, pads,
# Nearest to assembly: negotiating, votes, elections, smolensk, subtypes, amended, enciclopedia, vote,
# Nearest to quite: incapable, miyazaki, antonyms, onion, cultivar, nameable, sky, maize,
# Nearest to engine: engines, turbine, fuel, switch, mencken, preamplifier, generate, cylinders,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2626 0.2864 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2272 0.2291 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2302 0.2685 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1283 0.2252 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1793 0.2138 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1738 0.2102 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1401 0.2102 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1846 0.2903 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2147 0.2483 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1657 0.2421 sec/batch
# Nearest to most: unseated, evolutions, inflection, monarchy, seems, shotgun, horns, bastions,
# Nearest to s: lackey, ashmole, spalding, alexandrovna, narn, wallop, hon, analytics,
# Nearest to first: heisman, heir, was, oyama, lighthouses, excised, punch, post,
# Nearest to is: specifies, quantized, pris, isomorphic, categories, p, term, bijective,
# Nearest to about: drc, aloes, spam, manicheanism, preventable, discrepancies, tzar, daylight,
# Nearest to may: stopwatch, identically, readily, comprises, amine, analecta, banknote, hurdles,
# Nearest to its: outlying, distorts, trichechus, plymouth, asp, fraught, ethos, culturally,
# Nearest to th: jumblatt, teixeira, township, century, alain, glissandi, gagn, fia,
# Nearest to animals: genus, replicated, haircut, institutionalization, golfo, marvellous, isocrates, compasses,
# Nearest to experience: credible, why, critics, physical, royalties, therefore, witnesses, breakfasts,
# Nearest to universe: tidings, anus, cosmic, scientists, readings, hawking, aleinu, cosmological,
# Nearest to marriage: artha, miya, napol, sauvage, microarrays, cocteau, stedman, shamash,
# Nearest to engineering: faculty, marketing, electronics, philosophical, haq, technology, mechanical, rye,
# Nearest to assembly: votes, elections, negotiating, smolensk, vote, subtypes, cabinet, amended,
# Nearest to quite: incapable, miyazaki, antonyms, cultivar, nameable, onion, maize, sky,
# Nearest to engine: engines, turbine, fuel, reciprocating, mencken, cylinders, preamplifier, escalating,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1682 0.2085 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2400 0.1978 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1720 0.2221 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1792 0.2089 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1822 0.1970 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1879 0.1978 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2061 0.1980 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1834 0.1983 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1410 0.2043 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1524 0.2149 sec/batch
# Nearest to most: unseated, inflection, evolutions, shotgun, keep, horns, pine, bastions,
# Nearest to s: lackey, spalding, ashmole, alexandrovna, mcg, hon, analytics, pfa,
# Nearest to first: heir, heisman, was, philology, excised, tug, tenure, lighthouses,
# Nearest to is: isomorphic, quantized, specifies, categories, pris, bijective, p, term,
# Nearest to about: drc, aloes, preventable, chairperson, spam, whiteness, daylight, monstrous,
# Nearest to may: stopwatch, identically, comprises, readily, vid, analecta, banknote, guadalajara,
# Nearest to its: outlying, plymouth, distorts, staub, trichechus, fraught, culturally, ethos,
# Nearest to th: teixeira, jumblatt, century, township, muskie, augsburg, gagn, chechen,
# Nearest to animals: genus, replicated, haircut, institutionalization, golfo, marvellous, digestion, isocrates,
# Nearest to experience: credible, why, critics, physical, therefore, witnesses, putting, breakfasts,
# Nearest to universe: tidings, cosmic, anus, cosmological, hawking, energies, scientists, aleinu,
# Nearest to marriage: artha, miya, sauvage, microarrays, napol, cocteau, stedman, assignments,
# Nearest to engineering: electronics, faculty, philosophical, technology, marketing, development, haq, rye,
# Nearest to assembly: votes, elections, negotiating, vote, cabinet, smolensk, enciclopedia, subtypes,
# Nearest to quite: incapable, miyazaki, antonyms, nameable, cultivar, onion, basin, sky,
# Nearest to engine: engines, turbine, fuel, reciprocating, cylinders, escalating, propulsion, switch,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1651 0.2002 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1655 0.1995 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1821 0.1987 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1809 0.2025 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1762 0.1879 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1368 0.1877 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1836 0.1942 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1378 0.2041 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1978 0.1970 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2260 0.2137 sec/batch
# Nearest to most: unseated, evolutions, pine, inflection, bastions, major, shotgun, monarchy,
# Nearest to s: lackey, ashmole, spalding, alexandrovna, mcg, confirm, andrew, hon,
# Nearest to first: heir, was, heisman, tenure, post, philology, excised, vt,
# Nearest to is: quantized, categories, pris, subsistence, term, specifies, kickers, p,
# Nearest to about: drc, aloes, chairperson, tzar, daylight, fund, quaoar, macdonough,
# Nearest to may: stopwatch, identically, banknote, comprises, guadalajara, malpighi, excursions, vid,
# Nearest to its: outlying, plymouth, staub, fraught, culturally, insurrectionary, distorts, staunchly,
# Nearest to th: century, jumblatt, teixeira, township, augsburg, muskie, gagn, chechen,
# Nearest to animals: genus, replicated, haircut, institutionalization, marvellous, digestion, mashed, golfo,
# Nearest to experience: credible, putting, why, salons, unwittingly, kanons, breakfasts, business,
# Nearest to universe: cosmic, tidings, anus, hawking, cosmological, energies, scientists, zaghawa,
# Nearest to marriage: artha, miya, sauvage, microarrays, cocteau, shamash, stedman, napol,
# Nearest to engineering: electronics, faculty, technology, philosophical, marketing, development, haq, rye,
# Nearest to assembly: votes, negotiating, elections, cabinet, vote, smolensk, amended, subtypes,
# Nearest to quite: incapable, miyazaki, antonyms, cultivar, nameable, onion, basin, epitomized,
# Nearest to engine: engines, turbine, reciprocating, fuel, cylinders, escalating, propulsion, generate,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2225 0.2190 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1284 0.2374 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1110 0.2269 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1411 0.2043 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0448 0.2192 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1402 0.2210 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1671 0.2055 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1531 0.2098 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2023 0.0371 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0955 0.2168 sec/batch
# Nearest to most: major, evolutions, inflection, unseated, shotgun, bastions, intelligibility, keep,
# Nearest to s: lackey, spalding, mcg, ashmole, alexandrovna, wallop, pfa, hon,
# Nearest to first: was, heisman, heir, excised, tenure, ceo, post, tug,
# Nearest to is: specifies, quantized, categories, pris, bijective, or, p, term,
# Nearest to about: drc, aloes, tzar, chairperson, daylight, quaoar, fund, intramolecular,
# Nearest to may: stopwatch, identically, comprises, banknote, excursions, vid, analecta, date,
# Nearest to its: outlying, plymouth, trichechus, staub, fraught, culturally, asp, distorts,
# Nearest to th: century, jumblatt, teixeira, township, muskie, chechen, augsburg, gagn,
# Nearest to animals: genus, replicated, livers, marvellous, cows, institutionalization, species, mashed,
# Nearest to experience: credible, unwittingly, salons, putting, physical, why, imre, trivium,
# Nearest to universe: cosmic, tidings, cosmological, anus, hawking, energies, zaghawa, congo,
# Nearest to marriage: artha, miya, sauvage, microarrays, stedman, cocteau, shamash, cohorts,
# Nearest to engineering: electronics, technology, faculty, mechanical, philosophical, development, marketing, haq,
# Nearest to assembly: votes, negotiating, elections, cabinet, sovnarkom, amended, vote, smolensk,
# Nearest to quite: incapable, antonyms, miyazaki, nameable, cultivar, onion, maize, sky,
# Nearest to engine: engines, turbine, reciprocating, fuel, escalating, cylinders, camshaft, vorbis,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0780 0.2176 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0689 0.2056 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0723 0.2048 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0724 0.1974 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0855 0.2171 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0400 0.2041 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1230 0.2070 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0921 0.1944 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1376 0.1929 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0552 0.1934 sec/batch
# Nearest to most: unseated, evolutions, major, inflection, bastions, keep, monarchy, dalmatian,
# Nearest to s: lackey, spalding, mcg, confirm, hon, wallop, webcam, pfa,
# Nearest to first: was, heisman, heir, tenure, excised, both, ceo, punch,
# Nearest to is: quantized, specifies, bijective, or, must, makes, p, term,
# Nearest to about: drc, aloes, tzar, chairperson, daylight, fund, quaoar, vulture,
# Nearest to may: stopwatch, comprises, identically, excursions, banknote, readily, guadalajara, amine,
# Nearest to its: outlying, plymouth, culturally, staub, trichechus, gulf, asp, insurrectionary,
# Nearest to th: century, teixeira, jumblatt, township, muskie, augsburg, gagn, eight,
# Nearest to animals: genus, marvellous, mashed, replicated, cows, livers, institutionalization, conclusive,
# Nearest to experience: credible, unwittingly, physical, salons, business, breakfasts, patient, imre,
# Nearest to universe: cosmic, cosmological, hawking, tidings, energies, anus, congo, hirelings,
# Nearest to marriage: artha, miya, sauvage, microarrays, cocteau, shamash, stedman, cohorts,
# Nearest to engineering: electronics, technology, mechanical, philosophical, faculty, development, marketing, haq,
# Nearest to assembly: votes, elections, negotiating, cabinet, subtypes, vote, germain, sovnarkom,
# Nearest to quite: incapable, miyazaki, antonyms, onion, nameable, cultivar, hopeless, maize,
# Nearest to engine: engines, turbine, reciprocating, fuel, escalating, propulsion, camshaft, cylinders,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0194 0.1869 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0437 0.1965 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0096 0.2078 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0582 0.2027 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0833 0.2068 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0420 0.2110 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0506 0.1973 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0865 0.2017 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0357 0.2418 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0720 0.2032 sec/batch
# Nearest to most: evolutions, major, unseated, inflection, bastions, monarchy, intelligibility, metalworking,
# Nearest to s: lackey, spalding, mcg, sohn, hon, celesta, wallop, pfa,
# Nearest to first: was, heisman, heir, tenure, both, excised, vt, ceo,
# Nearest to is: quantized, or, bijective, the, categories, p, term, will,
# Nearest to about: drc, aloes, tzar, quaoar, vulture, chairperson, daylight, redemption,
# Nearest to may: comprises, stopwatch, identically, readily, banknote, excursions, amine, date,
# Nearest to its: outlying, plymouth, trichechus, staub, distorts, culturally, asp, specialisation,
# Nearest to th: century, teixeira, jumblatt, township, muskie, augsburg, eight, gagn,
# Nearest to animals: genus, replicated, marvellous, digestion, mashed, igf, cows, golfo,
# Nearest to experience: credible, trivium, business, unwittingly, patient, salons, putting, imre,
# Nearest to universe: cosmic, cosmological, hawking, energies, tidings, congo, anus, universes,
# Nearest to marriage: artha, sauvage, miya, microarrays, shamash, cocteau, stedman, assignments,
# Nearest to engineering: electronics, technology, faculty, mechanical, philosophical, development, institution, automobiles,
# Nearest to assembly: votes, negotiating, elections, subtypes, cabinet, appoints, vote, sovnarkom,
# Nearest to quite: antonyms, miyazaki, incapable, cultivar, onion, nameable, maize, hopeless,
# Nearest to engine: engines, turbine, reciprocating, fuel, camshaft, cylinders, escalating, piston,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0758 0.2055 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0883 0.2035 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0943 0.2026 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0410 0.2093 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0840 0.2229 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0600 0.2261 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0706 0.1950 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0503 0.2042 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0992 0.1992 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0549 0.2011 sec/batch
# Nearest to most: inflection, unseated, intelligibility, evolutions, major, monarchy, bastions, crusader,
# Nearest to s: lackey, spalding, confirm, mcg, migration, wallop, hon, celesta,
# Nearest to first: was, heir, tenure, ceo, both, philology, heisman, computer,
# Nearest to is: or, quantized, makes, bijective, term, categories, rationals, p,
# Nearest to about: drc, aloes, redemption, quaoar, daylight, fund, tzar, chairperson,
# Nearest to may: comprises, stopwatch, identically, banknote, excursions, readily, vid, malpighi,
# Nearest to its: outlying, plymouth, staub, trichechus, insurrectionary, feature, gulf, culturally,
# Nearest to th: century, teixeira, jumblatt, muskie, augsburg, township, chechen, gagn,
# Nearest to animals: genus, marvellous, replicated, cows, igf, species, mammals, digestion,
# Nearest to experience: credible, unwittingly, business, imre, putting, trivium, breakfasts, patient,
# Nearest to universe: cosmic, cosmological, energies, hawking, congo, tidings, hirelings, anus,
# Nearest to marriage: miya, sauvage, artha, microarrays, cocteau, cohorts, shamash, assignments,
# Nearest to engineering: electronics, technology, faculty, philosophical, mechanical, development, automobiles, haq,
# Nearest to assembly: negotiating, votes, subtypes, sovnarkom, germain, cabinet, appoints, amended,
# Nearest to quite: antonyms, miyazaki, incapable, cultivar, onion, nameable, basin, maize,
# Nearest to engine: engines, turbine, reciprocating, fuel, camshaft, escalating, viscosity, piston,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0481 0.2043 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0099 0.2121 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0347 0.2022 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0772 0.2048 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0885 0.2066 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1120 0.1981 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1297 0.2160 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0358 0.1988 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0384 0.2041 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0394 0.1980 sec/batch
# Nearest to most: unseated, major, evolutions, inflection, metalworking, intelligibility, bastions, crusader,
# Nearest to s: lackey, mcg, confirm, spalding, celesta, alexandrovna, wallop, caesars,
# Nearest to first: was, ceo, heir, tenure, heisman, both, computer, revitalised,
# Nearest to is: quantized, or, makes, bijective, p, term, specifies, characteristics,
# Nearest to about: drc, quaoar, fund, daylight, tzar, aloes, chairperson, habitability,
# Nearest to may: comprises, stopwatch, identically, excursions, banknote, date, vid, malpighi,
# Nearest to its: plymouth, outlying, staub, culturally, trichechus, gulf, insurrectionary, a,
# Nearest to th: century, jumblatt, muskie, teixeira, township, augsburg, chechen, rd,
# Nearest to animals: genus, marvellous, replicated, igf, cows, mashed, species, digestion,
# Nearest to experience: credible, imre, unwittingly, apiece, salons, putting, trivium, revolutionized,
# Nearest to universe: cosmic, cosmological, congo, tidings, energies, hawking, hirelings, universes,
# Nearest to marriage: sauvage, miya, artha, microarrays, cohorts, cocteau, shamash, stedman,
# Nearest to engineering: technology, electronics, faculty, philosophical, haq, mechanical, development, myers,
# Nearest to assembly: votes, negotiating, appoints, elections, amended, subtypes, cabinet, sovnarkom,
# Nearest to quite: antonyms, incapable, miyazaki, cultivar, nameable, onion, hopeless, maize,
# Nearest to engine: engines, turbine, reciprocating, fuel, camshaft, escalating, piston, viscosity,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9932 0.2076 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0169 0.2020 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0397 0.2046 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0289 0.2155 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0656 0.1975 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0594 0.1862 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9960 0.2084 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9890 0.2039 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9837 0.2312 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9496 0.2279 sec/batch
# Nearest to most: unseated, major, inflection, evolutions, crusader, intelligibility, arose, bastions,
# Nearest to s: lackey, spalding, migration, celesta, confirm, hon, mcg, caesars,
# Nearest to first: was, ceo, heisman, heir, tenure, captive, tug, both,
# Nearest to is: quantized, makes, or, p, bijective, term, the, characteristics,
# Nearest to about: drc, quaoar, tzar, daylight, fund, habitability, chairperson, aloes,
# Nearest to may: comprises, identically, stopwatch, malpighi, excursions, date, vid, banknote,
# Nearest to its: plymouth, outlying, trichechus, culturally, feature, a, staub, buttery,
# Nearest to th: century, jumblatt, township, teixeira, muskie, rd, nd, augsburg,
# Nearest to animals: genus, marvellous, replicated, igf, golfo, compasses, hormonal, carnivores,
# Nearest to experience: credible, imre, unwittingly, trivium, salons, apiece, patient, revolutionized,
# Nearest to universe: cosmic, cosmological, universes, congo, tidings, energies, hawking, hirelings,
# Nearest to marriage: sauvage, miya, artha, microarrays, cohorts, cocteau, shamash, stedman,
# Nearest to engineering: technology, electronics, mechanical, faculty, development, haq, automobiles, myers,
# Nearest to assembly: negotiating, votes, subtypes, appoints, germain, amended, corroborated, elections,
# Nearest to quite: antonyms, incapable, miyazaki, nameable, onion, cultivar, maize, russia,
# Nearest to engine: engines, turbine, reciprocating, camshaft, fuel, escalating, piston, viscosity,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9822 0.2115 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9669 0.1985 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0323 0.2020 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0271 0.1989 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0157 0.1979 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0106 0.2043 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9369 0.2017 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9596 0.1989 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9136 0.1994 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9781 0.2006 sec/batch
# Nearest to most: major, evolutions, bastions, metalworking, inflection, unseated, crusader, few,
# Nearest to s: lackey, spalding, celesta, hon, confirm, migration, mcg, caesars,
# Nearest to first: was, both, tenure, heisman, captive, heir, ceo, fiefs,
# Nearest to is: the, a, or, quantized, makes, of, must, term,
# Nearest to about: drc, quaoar, aloes, fund, tzar, daylight, chairperson, people,
# Nearest to may: comprises, identically, stopwatch, date, excursions, malpighi, readily, vid,
# Nearest to its: plymouth, outlying, buttery, culturally, feature, specialisation, trichechus, a,
# Nearest to th: century, jumblatt, township, teixeira, nd, muskie, augsburg, rd,
# Nearest to animals: marvellous, genus, replicated, igf, carnivores, hormonal, golfo, conclusive,
# Nearest to experience: imre, credible, revolutionized, unwittingly, trivium, physical, muds, salons,
# Nearest to universe: cosmic, cosmological, energies, hawking, universes, congo, tidings, bang,
# Nearest to marriage: sauvage, miya, microarrays, artha, cohorts, cocteau, shamash, assignments,
# Nearest to engineering: technology, electronics, mechanical, faculty, haq, automobiles, development, institution,
# Nearest to assembly: votes, negotiating, subtypes, cabinet, elections, appoints, amended, sovnarkom,
# Nearest to quite: antonyms, miyazaki, incapable, nameable, cultivar, onion, russia, einar,
# Nearest to engine: engines, turbine, reciprocating, camshaft, fuel, escalating, piston, viscosity,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9980 0.2055 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9864 0.2008 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9724 0.2015 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9999 0.2019 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0245 0.1998 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9688 0.1956 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0075 0.2039 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9819 0.2020 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9848 0.2094 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9893 0.2010 sec/batch
# Nearest to most: major, constantinople, inflection, metalworking, with, unseated, evolutions, bastions,
# Nearest to s: lackey, spalding, hon, celesta, sohn, confirm, of, analytics,
# Nearest to first: was, tenure, ceo, both, heisman, revitalised, heir, philology,
# Nearest to is: the, makes, a, or, quantized, term, will, of,
# Nearest to about: drc, quaoar, habitability, aloes, fund, chairperson, tzar, victims,
# Nearest to may: comprises, identically, stopwatch, date, vid, malpighi, excursions, readily,
# Nearest to its: plymouth, a, outlying, specialisation, buttery, ebbets, insurrectionary, mascarenhas,
# Nearest to th: century, township, muskie, jumblatt, nd, teixeira, rd, gagn,
# Nearest to animals: genus, marvellous, replicated, igf, carnivores, pest, hormonal, digestion,
# Nearest to experience: imre, trivium, credible, physical, revolutionized, business, unwittingly, patient,
# Nearest to universe: cosmic, cosmological, energies, universes, hawking, congo, bang, tidings,
# Nearest to marriage: sauvage, miya, microarrays, artha, assignments, divorced, adults, cocteau,
# Nearest to engineering: electronics, technology, mechanical, automobiles, development, haq, faculty, wavelength,
# Nearest to assembly: negotiating, subtypes, votes, cabinet, appoints, amended, elections, enciclopedia,
# Nearest to quite: antonyms, nameable, incapable, miyazaki, onion, cultivar, russia, einar,
# Nearest to engine: engines, turbine, reciprocating, camshaft, fuel, dragsters, viscosity, escalating,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0277 0.2133 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9783 0.2032 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9941 0.2046 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0160 0.1960 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0169 0.2017 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0055 0.2039 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9761 0.2038 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9709 0.2121 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9434 0.2084 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0166 0.2072 sec/batch
# Nearest to most: metalworking, unseated, constantinople, inflection, major, few, bastions, arose,
# Nearest to s: lackey, of, sohn, confirm, spalding, celesta, hon, mcg,
# Nearest to first: was, ceo, both, revitalised, tenure, based, heir, automobili,
# Nearest to is: the, or, a, makes, quantized, term, bijective, specifies,
# Nearest to about: drc, quaoar, fund, daylight, victims, aloes, chairperson, million,
# Nearest to may: comprises, identically, date, exceptions, excursions, readily, senate, ordinarily,
# Nearest to its: plymouth, a, outlying, by, buttery, from, the, gulf,
# Nearest to th: century, township, nd, teixeira, rd, jumblatt, muskie, augsburg,
# Nearest to animals: marvellous, genus, replicated, igf, carnivores, hormonal, golfo, roderick,
# Nearest to experience: credible, imre, revolutionized, unwittingly, apiece, physical, trivium, patient,
# ...
# Nearest to s: of, two, the, a, four, one, is, and,
# Nearest to first: in, was, after, the, successful, by, as, shutout,
# Nearest to is: a, of, the, in, for, from, or, an,
# Nearest to about: people, drc, it, wikipedians, births, discrepancies, in, victims,
# Nearest to may: or, exceptions, comprises, hymenoptera, date, end, southerly, ayahuasca,
# Nearest to its: the, in, a, of, for, an, from, as,
# Nearest to th: century, nd, rd, drill, approximate, early, township, centuries,
# Nearest to animals: humanoid, marvellous, predatory, patagonian, procured, replicated, pest, photorealistic,
# Nearest to experience: enjoying, scientologists, outsiders, putting, distortion, physical, therefore, illogical,
# Nearest to universe: cosmological, cosmic, universes, bang, gravitationally, congo, hirelings, hawking,
# Nearest to marriage: sauvage, divorced, divorce, microarrays, miya, adults, cocteau, countryman,
# Nearest to engineering: technology, mechanical, geotechnical, engineers, electronics, senior, siegel, faculty,
# Nearest to assembly: subtypes, appoints, reconstituted, watershed, parastatal, sovnarkom, corroborated, unicameral,
# Nearest to quite: antonyms, few, nameable, cultivar, expending, cities, einar, marchibroda,
# Nearest to engine: engines, camshaft, turbine, reciprocating, piston, enlightened, escalating, stroke,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8114 0.1790 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8768 0.1762 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8660 0.1792 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8593 0.1774 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8656 0.1775 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8775 0.1788 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8702 0.1776 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8621 0.1784 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8999 0.1801 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8476 0.1782 sec/batch
# Nearest to most: unseated, with, which, of, popular, is, in, major,
# Nearest to s: of, two, the, is, one, a, over, four,
# Nearest to first: was, in, after, by, successful, the, based, as,
# Nearest to is: a, of, the, in, from, for, with, or,
# Nearest to about: people, drc, wikipedians, zero, it, question, habitability, google,
# Nearest to may: exceptions, hymenoptera, date, comprises, or, southerly, end, ayahuasca,
# Nearest to its: the, in, a, of, from, for, an, as,
# Nearest to th: century, nd, rd, early, centuries, approximate, traditional, drill,
# Nearest to animals: humanoid, marvellous, patagonian, predatory, procured, photorealistic, replicated, troyes,
# Nearest to experience: enjoying, scientologists, outsiders, therefore, all, putting, distortion, physical,
# Nearest to universe: cosmic, cosmological, universes, gravitationally, bang, congo, hirelings, fargo,
# Nearest to marriage: sauvage, divorced, divorce, microarrays, miya, adults, countryman, absorb,
# Nearest to engineering: mechanical, geotechnical, technology, electronics, engineers, siegel, anu, haq,
# Nearest to assembly: subtypes, appoints, reconstituted, parastatal, unicameral, sovnarkom, legislative, watershed,
# Nearest to quite: antonyms, nameable, few, cultivar, expending, markschies, cities, proportionate,
# Nearest to engine: engines, camshaft, turbine, reciprocating, piston, enlightened, stroke, escalating,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8845 0.1805 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8266 0.1797 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8122 0.1783 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8254 0.1769 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8877 0.1782 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8551 0.1891 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9529 0.2036 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9168 0.1830 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9006 0.1922 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7902 0.2106 sec/batch
# Nearest to most: which, popular, of, more, is, many, with, unseated,
# Nearest to s: of, the, a, two, one, and, four, is,
# Nearest to first: was, after, in, the, of, published, by, eight,
# Nearest to is: a, of, the, for, in, has, or, makes,
# Nearest to about: people, wikipedians, zero, it, drc, two, births, million,
# Nearest to may: after, date, or, exceptions, hymenoptera, end, comprises, transitional,
# Nearest to its: the, in, a, of, an, from, and, as,
# Nearest to th: century, nd, rd, approximate, centuries, early, traditional, township,
# Nearest to animals: humanoid, marvellous, patagonian, predatory, troyes, procured, photorealistic, heb,
# Nearest to experience: enjoying, outsiders, scientologists, distortion, therefore, putting, schiphol, eclectic,
# Nearest to universe: cosmological, cosmic, universes, hirelings, fargo, congo, gravitationally, serialised,
# Nearest to marriage: divorced, sauvage, divorce, miya, microarrays, adults, annulled, spouses,
# Nearest to engineering: geotechnical, mechanical, electronics, technology, engineers, siegel, haq, anu,
# Nearest to assembly: subtypes, reconstituted, appoints, parastatal, sovnarkom, unicameral, aligned, legislative,
# Nearest to quite: antonyms, nameable, expending, few, cultivar, marchibroda, proportionate, simplistic,
# Nearest to engine: engines, camshaft, turbine, reciprocating, piston, stroke, enlightened, ignites,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7658 0.2143 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8877 0.1918 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7822 0.1944 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8804 0.1926 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8487 0.2082 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8822 0.1986 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8756 0.1144 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8337 0.1991 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8457 0.2020 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8330 0.1931 sec/batch
# Nearest to most: which, popular, with, is, many, very, unseated, more,
# Nearest to s: of, the, two, a, is, one, four, on,
# Nearest to first: was, in, after, the, of, a, by, eight,
# Nearest to is: a, of, the, from, in, an, for, with,
# Nearest to about: people, it, drc, juba, in, quaoar, lewdness, habitability,
# Nearest to may: hymenoptera, or, date, exceptions, ayahuasca, after, remarried, months,
# Nearest to its: the, in, a, from, an, is, of, for,
# Nearest to th: century, rd, nd, centuries, approximate, traditional, st, early,
# Nearest to animals: humanoid, marvellous, predatory, procured, heb, patagonian, photorealistic, troyes,
# Nearest to experience: enjoying, scientologists, outsiders, distortion, therefore, schiphol, putting, illogical,
# Nearest to universe: cosmological, cosmic, universes, hirelings, fargo, hastur, gravitationally, serialised,
# Nearest to marriage: divorced, sauvage, divorce, miya, microarrays, spouses, annulled, marry,
# Nearest to engineering: mechanical, geotechnical, electronics, technology, engineers, haq, anu, siegel,
# Nearest to assembly: subtypes, reconstituted, parastatal, appoints, sovnarkom, aligned, unicameral, watershed,
# Nearest to quite: antonyms, few, nameable, expending, cultivar, proportionate, cosines, core,
# Nearest to engine: engines, camshaft, turbine, reciprocating, piston, stroke, turboprop, sedan,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8051 0.1910 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8533 0.1954 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8169 0.1978 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7872 0.2010 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8418 0.1899 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8146 0.2134 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8696 0.2074 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7585 0.2388 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7880 0.2034 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8017 0.2021 sec/batch
# Nearest to most: of, with, which, in, many, major, is, as,
# Nearest to s: of, the, is, two, one, a, four, and,
# Nearest to first: in, was, after, the, by, as, of, eight,
# Nearest to is: a, of, the, in, for, from, an, as,
# Nearest to about: people, it, drc, breitman, wikipedians, juba, discrepancies, zero,
# Nearest to may: or, date, a, hymenoptera, exceptions, after, end, months,
# Nearest to its: in, the, for, an, a, of, and, from,
# Nearest to th: century, rd, nd, centuries, early, traditional, approximate, drill,
# Nearest to animals: humanoid, patagonian, predatory, marvellous, procured, heb, photorealistic, humane,
# Nearest to experience: enjoying, scientologists, outsiders, therefore, distortion, putting, physical, schiphol,
# Nearest to universe: cosmic, cosmological, universes, gravitationally, bang, hirelings, fargo, congo,
# Nearest to marriage: divorced, sauvage, divorce, microarrays, miya, spouses, annulled, marry,
# Nearest to engineering: geotechnical, engineers, mechanical, technology, electronics, haq, anu, sfa,
# Nearest to assembly: subtypes, reconstituted, unicameral, parastatal, appoints, watershed, aligned, sovnarkom,
# Nearest to quite: antonyms, few, cities, nameable, expending, cultivar, however, cosines,
# Nearest to engine: engines, camshaft, turbine, reciprocating, piston, turboprop, stroke, escalating,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7595 0.2004 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8259 0.1959 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8532 0.2055 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7958 0.1912 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8393 0.1920 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9155 0.1921 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8365 0.1981 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8273 0.1944 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8288 0.1900 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8142 0.1868 sec/batch
# Nearest to most: with, in, of, which, popular, unseated, more, referred,
# Nearest to s: of, one, two, a, is, the, four, in,
# Nearest to first: in, was, after, the, as, by, of, a,
# Nearest to is: a, of, the, in, an, for, from, to,
# Nearest to about: drc, people, breitman, it, wikipedians, discrepancies, zero, just,
# Nearest to may: or, date, end, a, exceptions, after, to, hymenoptera,
# Nearest to its: in, the, a, is, of, an, for, as,
# Nearest to th: century, rd, nd, traditional, centuries, early, drill, st,
# Nearest to animals: humanoid, predatory, patagonian, marvellous, humane, procured, heb, photorealistic,
# Nearest to experience: enjoying, outsiders, scientologists, therefore, distortion, putting, schiphol, eclectic,
# Nearest to universe: cosmic, cosmological, universes, gravitationally, bang, fargo, hawking, hirelings,
# Nearest to marriage: divorced, sauvage, divorce, miya, microarrays, spouses, marry, annulled,
# Nearest to engineering: geotechnical, technology, engineers, electronics, mechanical, haq, sfa, anu,
# Nearest to assembly: subtypes, unicameral, appoints, parastatal, reconstituted, legislative, cabinet, sovnarkom,
# Nearest to quite: antonyms, few, expending, cultivar, nameable, cities, however, proportionate,
# Nearest to engine: engines, camshaft, turbine, reciprocating, piston, stroke, turboprop, fuel,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8504 0.1925 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8516 0.1884 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8028 0.1903 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8376 0.1925 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8678 0.1975 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8194 0.1879 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8354 0.1903 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8456 0.1954 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8199 0.1947 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8193 0.1931 sec/batch
# Nearest to most: of, which, with, in, is, but, as, are,
# Nearest to s: of, a, two, one, the, is, four, with,
# Nearest to first: in, was, after, the, of, as, by, a,
# Nearest to is: a, of, the, in, for, an, from, with,
# Nearest to about: people, it, wikipedians, in, discrepancies, zero, just, juba,
# Nearest to may: or, a, date, to, end, after, the, exceptions,
# Nearest to its: in, the, of, a, an, as, by, and,
# Nearest to th: century, rd, nd, centuries, early, traditional, approximate, st,
# Nearest to animals: humanoid, patagonian, predatory, marvellous, procured, photorealistic, humane, swindle,
# Nearest to experience: enjoying, outsiders, scientologists, distortion, therefore, putting, schiphol, eclectic,
# Nearest to universe: cosmic, cosmological, universes, gravitationally, fargo, bang, hirelings, gan,
# Nearest to marriage: divorced, sauvage, divorce, miya, microarrays, adults, spouses, marry,
# Nearest to engineering: geotechnical, technology, electronics, engineers, mechanical, anu, haq, sfa,
# Nearest to assembly: reconstituted, subtypes, unicameral, appoints, sovnarkom, parastatal, cabinet, aligned,
# Nearest to quite: antonyms, expending, few, proportionate, cultivar, nameable, however, cosines,
# Nearest to engine: engines, camshaft, reciprocating, turbine, piston, stroke, turboprop, fuel,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8340 0.2070 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8270 0.1890 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9210 0.1917 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8918 0.2035 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8778 0.1879 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8517 0.2113 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7540 0.2146 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8493 0.2121 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7507 0.2113 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8513 0.2064 sec/batch
# Nearest to most: with, which, of, as, many, in, popular, very,
# Nearest to s: of, a, two, the, one, is, with, four,
# Nearest to first: in, was, after, a, the, of, by, published,
# Nearest to is: a, of, the, in, for, from, with, an,
# Nearest to about: people, it, wikipedians, discrepancies, drc, juba, just, breitman,
# Nearest to may: or, date, hymenoptera, a, exceptions, rents, after, prevent,
# Nearest to its: in, the, a, of, as, from, an, is,
# Nearest to th: century, rd, nd, centuries, traditional, early, st, approximate,
# Nearest to animals: humanoid, patagonian, predatory, procured, marvellous, humane, photorealistic, swindle,
# Nearest to experience: enjoying, scientologists, outsiders, distortion, dever, eclectic, therefore, putting,
# Nearest to universe: cosmological, cosmic, universes, hirelings, gravitationally, fargo, gan, bang,
# Nearest to marriage: divorced, sauvage, divorce, miya, microarrays, marry, wedding, spouses,
# Nearest to engineering: geotechnical, mechanical, technology, engineers, electronics, anu, haq, siegel,
# Nearest to assembly: subtypes, unicameral, reconstituted, parastatal, appoints, cabinet, aligned, sovnarkom,
# Nearest to quite: antonyms, expending, few, however, nameable, proportionate, polytechnique, cosines,
# Nearest to engine: engines, camshaft, reciprocating, turbine, piston, stroke, turboprop, fuel,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8276 0.2061 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8183 0.1955 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
